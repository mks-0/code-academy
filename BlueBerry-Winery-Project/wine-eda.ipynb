# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Import the CSVs
data_1 = pd.read_csv('data/winequality-red.csv', sep=';')
data_2 = pd.read_csv('data/winequality-white.csv', sep=';')
# Make copies of the dataframes
rw = data_1.copy()
ww = data_2.copy()

# %%
# Diplay first 10 and the last 10 records
display(rw.head(10))
display(rw.tail(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
display(ww.head(10))
display(ww.tail(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# Red Wine dataset consists of 1599 entries.

# %%
# Check for any missing data, kind of data types. View the Shape of the Datarame
print(rw.info(), '\n', rw.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
#  (1599, 12)

# %% [markdown]
# White Wine dataset consists of 4898 entries.

# %%
print(ww.info(), '\n', ww.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None
#  (4898, 12)

# %% [markdown]
# Both datasets have no missing values.

# %%
# Count of NaNs

print(rw.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(ww.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Red Wine dataset has 132 entries with 0 citric acid and white wine dataset has 19 of those.

# %%
# Count of zeros

print((rw == 0).sum())
print((ww == 0).sum())
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid             132
# residual sugar            0
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                   0
# pH                        0
# sulphates                 0
# alcohol                   0
# quality                   0
# dtype: int64
# fixed acidity            0
# volatile acidity         0
# citric acid             19
# residual sugar           0
# chlorides                0
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       0
# sulphates                0
# alcohol                  0
# quality                  0
# dtype: int64

# %%
display(rw.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
display(ww.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# Red Wine dataset includes 240 duplicates. \
# White Wine dataset includes 937 duplicates.

# %%
# Remove Duplicates
print(data_1.shape, '\n', data_1.duplicated().value_counts())
print(data_2.shape, '\n', data_2.duplicated().value_counts())
rw = rw.drop_duplicates()
ww = ww.drop_duplicates()
print(rw.duplicated().value_counts())
print(ww.duplicated().value_counts())
# Out:
# (1599, 12)
#  False    1359
# True      240
# dtype: int64
# (4898, 12)
#  False    3961
# True      937
# dtype: int64
# False    1359
# dtype: int64
# False    3961
# dtype: int64

# %% [markdown]
# I've created a new category called "Quality Label" and divided the samples into three groups: \
# LOW - samples with score 0 - 4 \
# MEDIUM - samples with score 5 - 7 \
# HIGH - samples with score 8 - 10

# %%
# Creating a new column called "quality label"
rw["quality label"] = rw["quality"].apply(
    lambda value: "low" if value < 5 else "medium" if value <= 7 else "high"
)
ww["quality label"] = ww["quality"].apply(
    lambda value: "low" if value < 5 else "medium" if value <= 7 else "high"
)

# Transforming these labels into categorical data type
categories=["low", "medium", "high"]
rw["quality label"] = pd.Categorical(
    rw["quality label"], categories=categories
)
ww["quality label"] = pd.Categorical(
    ww["quality label"], categories=categories
)

# %% [markdown]
# Merging two datasets into a third one.

# %%
# Creating a DataFrame of both wines

rw['wine type'] = 'Red'
ww['wine type'] = 'White'
rw['wine type'] = pd.Categorical(rw['wine type'], categories=['Red'])
ww['wine type'] = pd.Categorical(ww['wine type'], categories=['White'])
print(rw.shape[0] + ww.shape[0])
wine = pd.merge(rw, ww, how='outer')
print(wine.shape)
display(wine.head(5))
display(wine.tail(5))
# Out:
# 5320
# (5320, 14)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality quality label wine type
# ...

# %%
cols = [
    "residual sugar",
    "total sulfur dioxide",
    "sulphates",
    "citric acid",
    "volatile acidity",
    "quality",
]
pd.concat(
    [rw[cols].describe(), ww[cols].describe()],
    axis=1,
    keys=["Red Wines Stats", "White Wines Stats"],
)

# White Wine's Residual Sugar mean value is considerably higher
# Total Sulfur Dioxide mean value of White Wine is 3x higher that Red Wine's
# Volatile Acidity mean value of Red Wine is 2x higher that the White Wine's
# Out:
#       Red Wines Stats                                                 \
#        residual sugar total sulfur dioxide    sulphates  citric acid
# count     1359.000000          1359.000000  1359.000000  1359.000000
# mean         2.523400            46.825975     0.658705     0.272333
# std          1.352314            33.408946     0.170667     0.195537
# min          0.900000             6.000000     0.330000     0.000000
# 25%          1.900000            22.000000     0.550000     0.090000
# 50%          2.200000            38.000000     0.620000     0.260000
# 75%          2.600000            63.000000     0.730000     0.430000
# max         15.500000           289.000000     2.000000     1.000000
#
#                                     White Wines Stats                       \
#       volatile acidity      quality    residual sugar total sulfur dioxide
# count      1359.000000  1359.000000       3961.000000          3961.000000
# ...

# %% [markdown]
# Function to filter the outliers based on the 1.5 IQR range.

# %%
# Function for filtering outliers 

def filter_outliers(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = 1.5 * (q3 - q1)
    return data[(data > (q1 - iqr)) & (data < (q3 + iqr))]

# %%
sns.set_theme()
sns.set_style("darkgrid")
sns.set(rc={"figure.dpi":100, 'savefig.dpi':100})
sns.set_context('notebook')
# sns.set_style("ticks")

colors = ["#e60c34", "#fda929", "#19ae1d"]
colors_a = ["#e60c3460", "#fda92960", "#19ae1dff"]
colors_e = ["#e60c34", "#fd5a29", "#fda929", "#fcdf1c", "#73bf1d", "#19ae1d", "#1fd161"]
colors_w = ["#5798ff", "#c2006b"]

# Plot 1. Wine Type Count

wine["wine type"].value_counts().plot(
    kind="pie",
    figsize=(6, 6),
    textprops={"fontsize": 20},
    autopct="%1.1f%%",
    colors=colors_w,
    wedgeprops={"edgecolor": "#000000", "linewidth": 2},
    startangle=270
)

plt.title("Wine Type Count", fontsize=25)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Plot 2. Quality Labels Count

sns.countplot(data=wine, x='quality', palette=colors_e, edgecolor='black')
plt.ylabel('Count', fontsize=15)
plt.xlabel('Quality', fontsize=15)


fig, axes = plt.subplots(1, 2, sharey=True, figsize=(12, 5))

sns.countplot(data=rw, x='quality label', ax=axes[0], palette=colors, edgecolor='black')
axes[0].set_title('Red Wine', fontsize=20, pad=20)
axes[1].set_title('White Wine', fontsize=20, pad=20)
sns.countplot(data=ww, x='quality label', ax=axes[1], palette=colors, edgecolor='black')
[ax.set_ylabel("Count", fontsize=15, labelpad=15) for ax in axes]
[ax.set_xlabel("Quality", fontsize=15, labelpad=15) for ax in axes]
# Out:
# [Text(0.5, 0, 'Quality'), Text(0.5, 0, 'Quality')]

# %%
print(wine[wine['quality label'] == 'low'].value_counts().count())
print(wine[wine['quality label'] == 'medium'].value_counts().count())
print(wine[wine['quality label'] == 'high'].value_counts().count())
# Out:
# 236
# 4931
# 153

# %%
# Plot 3. Univariate Analysis of Red Wine compared to White Wine

n, m = 3, 4
fig, axes = plt.subplots(n, m, figsize=(7 * m, 5 * n))
fig.suptitle(
    "Univariate Analysis of Red Wine compared to White Wine", fontsize=30, y=0.92
)

k = 0

for i in range(n):
    k = i * m
    for j in range(m):
        sns.kdeplot(
        data=rw,
        x=filter_outliers(rw.iloc[:, k+j]),
        ax=axes[i][j],
        color=colors_w[1],
        fill=True,
        )
        sns.kdeplot(
        data=ww,
        x=filter_outliers(ww.iloc[:, k+j]),
        ax=axes[i][j], 
        color=colors_w[0],
        fill=True,
        )
        axes[i][j].set_xlabel(f'{rw.columns[k+j]}', fontsize=23, color="#6b6b6b")
        axes[i][j].set(yticklabels=[])
        axes[i][j].set(ylabel=None)
        
axes[n-1][m-1].set_visible(False)

# %%
# Plot 4. Univariate Analysis Wine between quality labels
def unvaq (data):
    n, m = 3, 4
    fig, axes = plt.subplots(n, m, figsize=(7 * m, 5 * n))
    fig.suptitle(
        f"Univariate Analysis of {data['wine type'][0]} Wine between Quality Labels", fontsize=30, y=0.92
    )
    k = 0
    for i in range(n):
        k = i * m
        for j in range(m):
            for l in range(len(categories)):
                sns.kdeplot(
                data=data,
                x=filter_outliers(data[data['quality label'] == categories[l]].iloc[:, k+j]),
                ax=axes[i][j],
                color=colors[l],
                fill=True,
                )
            axes[i][j].set_xlabel(f'{data.columns[k+j]}', fontsize=23, color="#6b6b6b")
            axes[i][j].set(yticklabels=[])
            axes[i][j].set(ylabel=None)
            
    axes[n-1][m-1].set_visible(False)
    plt.show()

unvaq(rw)
unvaq(ww)

# %%
# Plot 5. Wine Heatmap

data_list = [rw, ww, wine]
n = len(data_list)
wine_names= ['Red Wine', 'White Wine', 'Wine']
mask = np.triu(np.ones_like(rw.corr(numeric_only=True)))

for i in range(n):
    fig, axes = plt.subplots(figsize=(10, 8))
    fig.tight_layout(pad=9) 
    axes.set_title(wine_names[i], fontsize=15, pad=10)
    sns.heatmap(
        data_list[i].corr(numeric_only=True),
        annot=True,
        fmt=".2f",
        cmap="RdYlGn",
        mask=mask,
        vmin=-1,
        vmax=1,
    )
    plt.show()

# %%
# Plot 6. Red Wine Properties to Quality Label Correlation


def boxplot_quality(data, prop_list, type):
    n, m = 2, 3
    fig, axes = plt.subplots(n, m, figsize=(15, 10))
    k = 0
    if type == "box":
        for i in range(n):
            k = i * m
            for j in range(m):
                sns.boxplot(
                    data=data,
                    y=filter_outliers(data[prop_list[k + j]]),
                    x="quality label",
                    ax=axes[i][j],
                    palette=colors,
                    fliersize = 2,
                    boxprops=dict(edgecolor='black')
                )
                for patch in axes[i][j].patches:
                    r, g, b, a = patch.get_facecolor()
                    patch.set_facecolor((r, g, b, .7))
                plt.setp(axes[i][j].lines, zorder=100)
                sns.stripplot(
                    data=data,
                    y=filter_outliers(data[prop_list[k + j]]),
                    x="quality label",
                    ax=axes[i][j],
                    palette=colors,
                    hue='quality label',
                    jitter=0.4,
                    alpha=0.38,
                    size=3
                )
                axes[i][j].legend([], [], frameon=False)       
    # else:
    #     for i in range(n):
    #         k = i * m
    #         for j in range(m):
    #             sns.boxenplot(
    #                 data=data,
    #                 y=filter_outliers(data[prop_list[k + j]]),
    #                 x="quality",
    #                 ax=axes[i][j],
    #                 palette=colors_e,
    #                 flier_kws = {'s': 7},
    #             )
    if data['wine type'][0] == 'Red':
        fig.suptitle("Red Wine Properties to Quality Label Correlation ", fontsize=20)
        # axes[1][2].set_visible(False)
    else:
        fig.suptitle("White Wine Properties to Quality Label Correlation ", fontsize=20)
        # axes[0][2].set_visible(False)
    plt.show()


rw_props_list = [
    "sulphates",
    "citric acid",
    "alcohol",
    "density",
    "volatile acidity",
    "chlorides",
]
ww_props_list = [
    "pH",
    "alcohol",
    "free sulfur dioxide",
    "density",
    "chlorides",
    "volatile acidity",
]
boxplot_quality(rw, rw_props_list, "box")
boxplot_quality(ww, ww_props_list, "box")

# %%
# Plot 7. Bivariate Analysis. KDE and Scatter Plots.

def kde_scatter_plot(data, x, y):
    hue_order = ["high", "medium", "low"]
    fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
    fig.suptitle(
        f"{data['wine type'][0]} Wine \n {x.name.title()} to {y.name.title()}",
        fontsize=20,
    )
    sns.kdeplot(
        data=data,
        y=filter_outliers(y),
        x=filter_outliers(x),
        hue="quality label",
        palette=colors,
        levels=10,
        ax=axes[0],
    )
    sns.scatterplot(
        data=data,
        y=filter_outliers(y),
        x=filter_outliers(x),
        hue="quality label",
        palette=colors_a,
        ax=axes[1],
        marker="s",
        s=25,
        linewidth=0,
    )
    plt.legend([], [], frameon=False)
    plt.show()

# %%
# kde_scatter_plot(rw, rw["density"], rw["alcohol"])
# kde_scatter_plot(rw, rw["density"], rw["residual sugar"])
# kde_scatter_plot(rw, rw["density"], rw["fixed acidity"])
# kde_scatter_plot(rw, rw["citric acid"], rw["fixed acidity"])
# kde_scatter_plot(rw, rw["pH"], rw["fixed acidity"])
# kde_scatter_plot(rw, rw["citric acid"], rw["volatile acidity"])
# kde_scatter_plot(rw, rw["citric acid"], rw["pH"])
# kde_scatter_plot(rw, rw["density"], rw["pH"])
# kde_scatter_plot(rw, rw["chlorides"], rw["sulphates"])

# %%
# kde_scatter_plot(ww, ww["pH"], ww["fixed acidity"])
# kde_scatter_plot(ww, ww["alcohol"], ww["residual sugar"])
# kde_scatter_plot(ww, ww["density"], ww["residual sugar"])
# kde_scatter_plot(ww, ww["free sulfur dioxide"], ww["residual sugar"])
# kde_scatter_plot(ww, ww["density"], ww["total sulfur dioxide"])
# kde_scatter_plot(ww, ww["density"], ww["alcohol"])
# kde_scatter_plot(ww, ww["chlorides"], ww["alcohol"])

# %%
# Plot 8. Finding a factor 0 < k < 1, that would represent quality based on wine properties.
# The bigger the factor, the better the quality suppose to be.

k_r = (rw["citric acid"] + rw["alcohol"] + rw["sulphates"]) / (rw["density"] + rw["volatile acidity"])
rw["factor"] = k_r / k_r.abs().max()
k_w = (ww["pH"] + ww["alcohol"]) / (
    ww["density"] + ww["volatile acidity"] + ww["chlorides"]
)
ww["factor"] = k_w / k_w.abs().max()

n = 2
fig, axes = plt.subplots(1, n, figsize=(11, 5), sharey=True)
fig.suptitle("Quality Factor", fontsize=20, y=1.1)
q = 'quality'

for i in range(n):
    c = colors_e[:-1] if i == 0 else colors_e
    axes[i].set_title(wine_names[i], fontsize=15)
    sns.boxplot(
        data=data_list[i],
        x=q,
        y="factor",
        palette=c,
        ax=axes[i],
        fliersize=0,
        # linewidth=1,
        
    )
    # for patch in axes[i].patches:
    #     r, g, b, a = patch.get_facecolor()
    #     patch.set_facecolor((r, g, b, .5))
    # plt.setp(axes[i].lines, zorder=100)
    # sns.stripplot(
    #     data=data_list[i],
    #     x=q,
    #     y="factor",
    #     palette=c,
    #     hue=q,
    #     ax=axes[i],
    #     s=2,
    #     jitter=0.4,
    #     alpha=0.5,
    # )
    axes[i].legend([], [], frameon=False)

# %% [markdown]
# $ {\huge k_{rw}=\frac{citric\:acid + alcohol + sulphates}{density + volatile\:acidity}} $ \
# \
# $ {\huge k_{ww}=\frac{pH + alcohol}{density + volatile\:acidity + chlorides}} $

# %%
# Testing the probability and ANOVA of the factor

from scipy import stats

def k_prob(data, q):
    q_labels = ["low", "medium", "high"]
    n = q_labels.index(q)
    dql = data["quality label"]
    if n == 0:
        a = data[(data["factor"] < data[dql == q]["factor"].mean()) & (dql == q)]
    else:
        a = data[
            (data["factor"] > data[dql == q_labels[n - 1]]["factor"].mean())
            & (dql == q)
        ]
    return a.value_counts().count() / data[dql == q].value_counts().count()


print(k_prob(rw, "low"), k_prob(rw, "medium"), k_prob(rw, "high"))
print(k_prob(ww, "low"), k_prob(ww, "medium"), k_prob(ww, "high"))
print("\n")

F, p = stats.f_oneway(
    rw[rw["quality label"] == "low"]["factor"],
    rw[rw["quality label"] == "medium"]["factor"],
    rw[rw["quality label"] == "high"]["factor"],
)
print(
    "ANOVA test for mean factor levels across wine samples with different quality ratings"
)
print("F Statistic:", F, "\tp-value:", p)
# Out:
# 0.6031746031746031 0.763096168881939 0.9411764705882353
# 0.47398843930635837 0.7642387732749178 0.8823529411764706
#
#
# ANOVA test for mean factor levels across wine samples with different quality ratings
# F Statistic: 36.674026804556455 	p-value: 3.079705268193502e-16

# %%
# ANOVA Testing

F, p = stats.f_oneway(
    rw[rw["quality label"] == "low"]["alcohol"],
    rw[rw["quality label"] == "medium"]["alcohol"],
    rw[rw["quality label"] == "high"]["alcohol"],
)
print(
    "ANOVA test for mean alcohol levels across wine samples with different quality ratings"
)
print("F Statistic:", F, "\tp-value:", p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 23.752501855035085 	p-value: 7.261076778314764e-11

# %%
for prop in rw:
    if prop != 'quality label' and prop != 'wine type':
        F, p = stats.f_oneway(
            rw[rw["quality label"] == "low"][prop],
            rw[rw["quality label"] == "medium"][prop],
            rw[rw["quality label"] == "high"][prop],
        )
    if p > 0.05:
        print(prop)
# Out:
# fixed acidity
# residual sugar
# chlorides

# %%
# Calculate skewness and kurtosis
print(filter_outliers(rw['chlorides']).astype(float).skew())
print(rw['citric acid'].astype(float).kurt())
# Out:
# 0.22547937266119336
# -0.7889205005417139

# %%
wine.to_csv('data/processed/wine.csv', index=False)
rw.to_csv('data/processed/red_wine_p.csv', index=False)
ww.to_csv('data/processed/white_wine_p.csv', index=False)
