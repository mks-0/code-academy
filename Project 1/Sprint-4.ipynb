# %%
import numpy as np
import pandas as pd
import random

df = pd.read_csv('Sprint 1 - Movies Data Set Analysis/movies.csv') # Gathering data
df = df.drop(columns=['Summary']) # remove the column "Summary"
df.columns = df.columns.str.lower().str.replace(' ', '_') # Make all the column names lowercase and replace spaces with underscores
df.drop(df.tail(1).index, inplace=True) # Remove the last row of the DF (containing NaNs)

# %%
display(df.tail(5)) # See the first five rows of the Data Frame
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
#             gross release_date      genre  runtime  rating  rating_count
# 610  3.859000e+08   2019-05-13  Adventure    132.0     NaN           NaN
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN

# %%
# Fill NaNs with a random value between (mean — 2 * std) & (mean + 2 * std)

def nan_rand_fill(data, key):
    mn = data[key].mean()
    sd = data[key].std()
    low_l = mn - 2 * sd
    high_l = mn + 2 * sd
    nans = data[key].isna()
    df.loc[nans, key] = [abs(np.floor(random.uniform(low_l, high_l))) 
                         if 'count' in key 
                         else abs(round(random.uniform(low_l, high_l), 1)) 
                         for i in range(nans.sum())]

nan_rand_fill(df, 'rating')
nan_rand_fill(df, 'rating_count')

# %%
# Fill NaNs with a median value
# df["rating"].fillna(value=df["rating"].median(), inplace=True)

# %%
display(df.tail(5)) # See the first five rows of the Data Frame
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
#             gross release_date      genre  runtime  rating  rating_count
# 610  3.859000e+08   2019-05-13  Adventure    132.0     6.4      762180.0
# 611  1.062000e+09   2019-06-11  Animation    100.0     8.4      294574.0
# 612  7.594000e+08   2019-07-13   Thriller    136.0     5.7      570536.0
# 613  1.632000e+09   2019-07-09      Drama    118.0     6.3      201223.0
# 614  2.796000e+09   2019-04-22     Action    181.0     5.2      508950.0

# %%
print(df.shape) # Shape of the Data Frame
# Out:
# (615, 10)

# %%
print(df.dtypes) # Column names with their data types
# Out:
# movieid           int64
# title            object
# mpaa_rating      object
# budget          float64
# gross           float64
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
print(df.columns) # Column names
# Out:
# Index(['movieid', 'title', 'mpaa_rating', 'budget', 'gross', 'release_date',
#        'genre', 'runtime', 'rating', 'rating_count'],
#       dtype='object')

# %%
print(df.isna().sum()) # Column names with their NaN count
# Out:
# movieid         0
# title           0
# mpaa_rating     0
# budget          0
# gross           0
# release_date    0
# genre           0
# runtime         0
# rating          0
# rating_count    0
# dtype: int64

# %%
df.drop_duplicates(subset=['title', 'release_date']) # Remove row duplicates by title and release date
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
#             gross release_date      genre  runtime  rating  rating_count
# 0    2.960000e+08   1989-10-12    Romance     93.0     5.9       73638.0
# 1    1.457933e+08   1989-12-13     Comedy     99.0     7.4       91075.0
# 2    7.107992e+07   1989-07-28      Crime    100.0     7.2       91415.0
# 3    1.610017e+08   1989-12-20        War    145.0     7.2       91415.0
# 4    8.443162e+07   1989-04-21      Drama    107.0     7.5      101702.0
# ..            ...          ...        ...      ...     ...           ...
# 610  3.859000e+08   2019-05-13  Adventure    132.0     6.4      762180.0
# 611  1.062000e+09   2019-06-11  Animation    100.0     8.4      294574.0
# 612  7.594000e+08   2019-07-13   Thriller    136.0     5.7      570536.0
# 613  1.632000e+09   2019-07-09      Drama    118.0     6.3      201223.0
# 614  2.796000e+09   2019-04-22     Action    181.0     5.2      508950.0
#
# [615 rows x 10 columns]

# %%
# Convert data types (Converted float64 to int64 so the high gross and budget values won't overflow the int)

df['budget'] = df['budget'].astype(np.int64)
df['gross'] = df['gross'].astype(np.int64, errors='raise')
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
print(df.dtypes)
# Out:
# movieid                  int64
# title                   object
# mpaa_rating             object
# budget                   int64
# gross                    int64
# release_date    datetime64[ns]
# genre                   object
# runtime                float64
# rating                 float64
# rating_count           float64
# dtype: object

# %%
df.tail(10)
# Out:
#      movieid                                  title mpaa_rating     budget  \
# 605      606              Pokemon Detective Pikachu          PG  150000000
# 606      607              Spider-Man: Far from Home       PG-13  160000000
# 607      608                                  Dumbo          PG  170000000
# 608      609                         Captain Marvel       PG-13  175000000
# 609      610                                Aladdin          PG  183000000
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 605   431600000   2019-05-03    Mystery    104.0     5.4      779103.0
# 606  1131000000   2019-06-26     Action    129.0     6.3      122264.0
# 607   353000000   2019-03-11  Adventure    112.0     5.3      915162.0
# 608  1128000000   2019-02-27     Action    124.0     7.8       82308.0
# 609  1049000000   2019-05-08    Fantasy    128.0     7.3      404211.0
# 610   385900000   2019-05-13  Adventure    132.0     6.4      762180.0
# 611  1062000000   2019-06-11  Animation    100.0     8.4      294574.0
# 612   759400000   2019-07-13   Thriller    136.0     5.7      570536.0
# 613  1632000000   2019-07-09      Drama    118.0     6.3      201223.0
# 614  2796000000   2019-04-22     Action    181.0     5.2      508950.0

# %%
# Show the movies with more than 7 in Rating & greater than 50 million Gross
display(df[(df['rating'] > 7) & (df['gross'] > 50000000)])
# Out:
#      movieid                              title mpaa_rating     budget  \
# 1          2                 Driving Miss Daisy          PG    7500000
# 2          3                     Turner & Hooch          PG   13000000
# 3          4         Born on the Fourth of July           R   14000000
# 4          5                    Field of Dreams          PG   15000000
# 6          7            When Harry Met Sally...           R   16000000
# ..       ...                                ...         ...        ...
# 601      602      Once Upon a Time in Hollywood           R   96000000
# 602      603  The LEGO Movie 2: The Second Part          PG   99000000
# 608      609                     Captain Marvel       PG-13  175000000
# 609      610                            Aladdin          PG  183000000
# 611      612                        Toy Story 4           G  200000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 1     145793296   1989-12-13     Comedy     99.0     7.4       91075.0
# 2      71079915   1989-07-28      Crime    100.0     7.2       91415.0
# 3     161001698   1989-12-20        War    145.0     7.2       91415.0
# 4      84431625   1989-04-21      Drama    107.0     7.5      101702.0
# 6      92800000   1989-07-21    Romance     96.0     7.6      180871.0
# ..          ...          ...        ...      ...     ...           ...
# 601   345900000   2019-05-21     Comedy    161.0     8.1      937958.0
# 602   191300000   2019-02-07  Animation    107.0     8.1      469091.0
# 608  1128000000   2019-02-27     Action    124.0     7.8       82308.0
# 609  1049000000   2019-05-08    Fantasy    128.0     7.3      404211.0
# 611  1062000000   2019-06-11  Animation    100.0     8.4      294574.0
#
# [267 rows x 10 columns]

# %%
# Show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating
display(df[(df['rating'] > 7) 
           & (df['gross'] > 50000000) 
           & (df['mpaa_rating'] == 'PG')])
# Out:
#      movieid                              title mpaa_rating     budget  \
# 1          2                 Driving Miss Daisy          PG    7500000
# 2          3                     Turner & Hooch          PG   13000000
# 4          5                    Field of Dreams          PG   15000000
# 7          8                 Dead Poets Society          PG   16400000
# 13        14                             Batman          PG   35000000
# ..       ...                                ...         ...        ...
# 581      582  Spider-Man: Into the Spider-Verse          PG   90000000
# 591      592                      Incredibles 2          PG  200000000
# 600      601          The Secret Life of Pets 2          PG   80000000
# 602      603  The LEGO Movie 2: The Second Part          PG   99000000
# 609      610                            Aladdin          PG  183000000
#
#           gross release_date      genre  runtime  rating  rating_count
# 1     145793296   1989-12-13     Comedy     99.0     7.4       91075.0
# 2      71079915   1989-07-28      Crime    100.0     7.2       91415.0
# 4      84431625   1989-04-21      Drama    107.0     7.5      101702.0
# 7     235860116   1989-06-02      Drama    129.0     8.1      382002.0
# 13    411348924   1989-06-23     Action    126.0     7.5      319517.0
# ..          ...          ...        ...      ...     ...           ...
# 581   375500000   2018-12-01  Animation    117.0     8.3       29542.0
# 591  1242000000   2018-06-05  Animation    118.0     7.9       58300.0
# 600   429400000   2019-05-24  Animation     86.0     7.2      670795.0
# 602   191300000   2019-02-07  Animation    107.0     8.1      469091.0
# 609  1049000000   2019-05-08    Fantasy    128.0     7.3      404211.0
#
# [65 rows x 10 columns]

# %%
# Count of Animation movies with more than 7 in Rating (use the shape() function)
print(df[(df['genre'] == 'Animation') & (df['rating'] > 7)].shape[0])
# Out:
# 49

# %%
# Show the list of top 5 movies based on Budget
display(df.sort_values('budget', ascending=False).head(5))
# Out:
#      movieid                                        title mpaa_rating  \
# 594      595                       Avengers: Infinity War       PG-13
# 454      455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614      615                            Avengers: Endgame       PG-13
# 574      575                     Star Wars: The Last Jedi       PG-13
# 375      376     Pirates of the Caribbean: At World's End       PG-13
#
#         budget       gross release_date            genre  runtime  rating  \
# 594  400000000  2048000000   2018-04-23           Action    149.0     5.9
# 454  380000000  1045713802   2011-05-14           Action    136.0     6.6
# 614  356000000  2796000000   2019-04-22           Action    181.0     5.2
# 574  317000000  1333000000   2019-12-09  Science Fiction    152.0     6.2
# 375  300000000   961000000   2007-05-19        Adventure    169.0     7.1
#
#      rating_count
# 594      865949.0
# 454      455211.0
# 614      508950.0
# 574      875987.0
# 375      565402.0

# %%
# Show the top 5 Comedy movies by Rating
display(df[df['genre'] == 'Comedy'].sort_values('rating', ascending=False).head(5))
# Out:
#      movieid                          title mpaa_rating    budget      gross  \
# 111      112                   Forrest Gump       PG-13  55000000  677945399
# 516      517                Pitch Perfect 2       PG-13  29000000  287506194
# 601      602  Once Upon a Time in Hollywood           R  96000000  345900000
# 185      186                The Truman Show          PG  60000000  264118201
# 80        81                  Groundhog Day          PG  14600000   70906973
#
#     release_date   genre  runtime  rating  rating_count
# 111   1994-07-06  Comedy    142.0     8.8     1657851.0
# 516   2015-05-07  Comedy    115.0     8.2      473483.0
# 601   2019-05-21  Comedy    161.0     8.1      937958.0
# 185   1998-06-04  Comedy    103.0     8.1      859224.0
# 80    1993-02-11  Comedy    101.0     8.0      549538.0

# %%
# Top 5 movie names by Rating
print(df.loc[df.sort_values('rating', ascending=False).head(5).index, 'title'])
# Out:
# 393                                  The Dark Knight
# 98                                 Jurassic Park III
# 99                                      Pulp Fiction
# 287    The Lord of the Rings: The Return of the King
# 83                                  Schindler's List
# Name: title, dtype: object

# %%
# Top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)
print(
    df.loc[df[
        (df['genre'] == 'Romance') &
        (df['release_date'] > pd.Timestamp('1999-12-31'))
    ] 
    .sort_values('gross', ascending=False) 
    .head(3) 
    .index, 'title']
)
# Out:
# 464    The Twilight Saga: Breaking Dawn - Part 2
# 442    The Twilight Saga: Breaking Dawn - Part 1
# 401                  The Twilight Saga: New Moon
# Name: title, dtype: object

# %%
# How many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)
print(df['genre'].value_counts())
# Out:
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: genre, dtype: int64

# %%
# Top 5 expensive movies released after 1999, not included (measured by Budget)
print(df.loc[df[df['release_date'] > pd.Timestamp('1999-12-31')].sort_values('budget', ascending=False).head(5).index, 'title'])
# Out:
# 594                         Avengers: Infinity War
# 454    Pirates of the Caribbean: On Stranger Tides
# 614                              Avengers: Endgame
# 574                       Star Wars: The Last Jedi
# 573                                 Justice League
# Name: title, dtype: object

# %%
# Most & least frequent MPAA Rating in the dataset in terms of occurrences
# print(df['mpaa_rating'].value_counts())
print(f"The most frequent MPAA Rating is {df['mpaa_rating'].value_counts().index[0]}")
print(f"The most frequent MPAA Rating is {df['mpaa_rating'].mode()[0]}")
print(f"The least frequent MPAA Rating is {df['mpaa_rating'].value_counts().index[-1]}")
# Out:
# The most frequent MPAA Rating is PG-13
# The most frequent MPAA Rating is PG-13
# The least frequent MPAA Rating is G

# %%
# Most and least expensive Genre (take an average of all Budget measures grouped by Genre - use groupBy() method)
print(f"Most expensive genre is {df.groupby('genre')['budget'].mean().sort_values(ascending=False).index[0]}")
print(f"Least expensiv genre is {df.groupby('genre')['budget'].mean().sort_values(ascending=False).index[-1]}")
# Out:
# Most expensive genre is Fantasy
# Least expensiv genre is Horror

# %%
# Which Genre is favored the most by the people?
# print(df.groupby('genre')['rating'].mean().sort_values(ascending=False))
print(f"The most favored genre is {df.groupby('genre')['gross'].mean().sort_values(ascending=False).index[0]}")
# Out:
# The most favored genre is Fantasy

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

#Plot 1. Bar Chart - Genre Movie Count

ax = df.groupby('genre')['genre'].count().sort_values(ascending=False).plot(kind='bar', color='#E15759', width=0.8, figsize=(10, 7))
ax.set_yticks(range(0, 120, 10))
[ax.spines[spine].set_visible(False) for spine in ['top', 'right', 'bottom', 'left']]

plt.title('Genre Movie Count', fontsize=20, pad=30)
plt.xticks(rotation='vertical', fontsize=10, color="grey")
plt.yticks(color='grey')
plt.ylabel("Count of Genre")
plt.xlabel("Genres")
# Out:
# Text(0.5, 0, 'Genres')

# %%
#Plot 2. Box Chart - Genre to Rating

boxprops = dict(color='blue', facecolor=(0, 0, 1, 0.2))
flierprops = dict(
    marker='o', 
    markerfacecolor=(1, 0, 0, 0.5), 
    markeredgecolor='none', 
    markersize=5
    )
medianprops = dict(linewidth=3, color=(1, 0.9, 0, 1))
ax = df.boxplot(
    by='genre', 
    column=['rating'], 
    figsize=(12, 9), 
    boxprops=boxprops, 
    flierprops=flierprops,
    medianprops=medianprops, 
    whis=[1, 99], 
    patch_artist = True
    )

fig = ax.get_figure()
fig.suptitle('')
ax.set_yticks(np.arange(4, 10, 0.5))
[ax.spines[spine].set_visible(False) 
 for spine in ['top', 'right', 'bottom', 'left']]

plt.title('Genre to Rating', fontsize=20, pad=30)
plt.xticks(rotation='vertical', fontsize=10, color="grey")
plt.yticks(color='grey')
plt.ylabel("Rating", fontsize=15)
plt.xlabel("Genres", fontsize=15)
# Out:
# Text(0.5, 0, 'Genres')

# %%
#Plot 3. Histogram - Runtime Distribution

ax = plt.axes()
fig = ax.get_figure()
fig.set_size_inches(10 ,7)

hg = df.hist(column='runtime', bins=np.arange(70, 210, 10), color=(1, 0.68, 0), width=9, ax=ax)
[ax.spines[spine].set_visible(False) for spine in ['top', 'right', 'bottom', 'left']]
ax.set_xticks(np.arange(70, 210, 10))

plt.title('Runtime Distribution', fontsize=20, pad=30)
plt.xticks(rotation='vertical', fontsize=10, color="grey")
plt.yticks(color='grey')
plt.ylabel("Frequency", fontsize=15, labelpad=20)
plt.xlabel("Runtime (bins)", fontsize=15, labelpad=20)
# Out:
# Text(0.5, 0, 'Runtime (bins)')

# %%
#Plot 4. Pie Chart - MPAA Rating to Gross

colors = ['#59a14f', '#f28e2b', '#9d53f2', '#e15759']
explode = (0, 0 ,0 ,0)
textprops = {'fontsize': 16}
pie = df.groupby(['mpaa_rating'])['gross'].sum().plot(
    kind='pie', y='gross',
    autopct='%1.0f%%', 
    figsize=(9, 9),colors=colors, 
    explode=explode, 
    textprops=textprops, 
    labeldistance=1.1, 
    pctdistance=0.8
    )
hole = plt.Circle((0, 0), 0.6, facecolor='white')
plt.title('MPAA Rating to Gross', fontsize=20, pad=30)
plt.gcf().gca().add_artist(hole)
plt.xlabel("Gross", fontsize=20, labelpad=20)
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
