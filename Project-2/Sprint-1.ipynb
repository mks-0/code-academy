# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Import the CSVs
data_1 = pd.read_csv('data/winequality-red.csv', sep=';')
data_2 = pd.read_csv('data/winequality-white.csv', sep=';')
# Make copies of the dataframes
rw = data_1.copy()
ww = data_2.copy()

# %%
# Diplay first 10 and the last 10 records
display(rw.head(10))
display(rw.tail(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        7.40000           0.70000      0.00000         1.90000    0.07600
# 1        7.80000           0.88000      0.00000         2.60000    0.09800
# 2        7.80000           0.76000      0.04000         2.30000    0.09200
# 3       11.20000           0.28000      0.56000         1.90000    0.07500
# 4        7.40000           0.70000      0.00000         1.90000    0.07600
# 5        7.40000           0.66000      0.00000         1.80000    0.07500
# 6        7.90000           0.60000      0.06000         1.60000    0.06900
# 7        7.30000           0.65000      0.00000         1.20000    0.06500
# 8        7.80000           0.58000      0.02000         2.00000    0.07300
# 9        7.50000           0.50000      0.36000         6.10000    0.07100
#
#    free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 0             11.00000              34.00000  0.99780 3.51000    0.56000
# 1             25.00000              67.00000  0.99680 3.20000    0.68000
# 2             15.00000              54.00000  0.99700 3.26000    0.65000
# 3             17.00000              60.00000  0.99800 3.16000    0.58000
# 4             11.00000              34.00000  0.99780 3.51000    0.56000
# 5             13.00000              40.00000  0.99780 3.51000    0.56000
# 6             15.00000              59.00000  0.99640 3.30000    0.46000
# 7             15.00000              21.00000  0.99460 3.39000    0.47000
# 8              9.00000              18.00000  0.99680 3.36000    0.57000
# 9             17.00000             102.00000  0.99780 3.35000    0.80000
#
#    alcohol  quality
# 0  9.40000        5
# 1  9.80000        5
# 2  9.80000        5
# 3  9.80000        6
# 4  9.40000        5
# 5  9.40000        5
# 6  9.40000        5
# 7 10.00000        7
# 8  9.50000        7
# 9 10.50000        5
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589        6.60000           0.72500      0.20000         7.80000    0.07300
# 1590        6.30000           0.55000      0.15000         1.80000    0.07700
# 1591        5.40000           0.74000      0.09000         1.70000    0.08900
# 1592        6.30000           0.51000      0.13000         2.30000    0.07600
# 1593        6.80000           0.62000      0.08000         1.90000    0.06800
# 1594        6.20000           0.60000      0.08000         2.00000    0.09000
# 1595        5.90000           0.55000      0.10000         2.20000    0.06200
# 1596        6.30000           0.51000      0.13000         2.30000    0.07600
# 1597        5.90000           0.64500      0.12000         2.00000    0.07500
# 1598        6.00000           0.31000      0.47000         3.60000    0.06700
#
#       free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 1589             29.00000              79.00000  0.99770 3.29000    0.54000
# 1590             26.00000              35.00000  0.99314 3.32000    0.82000
# 1591             16.00000              26.00000  0.99402 3.67000    0.56000
# 1592             29.00000              40.00000  0.99574 3.42000    0.75000
# 1593             28.00000              38.00000  0.99651 3.42000    0.82000
# 1594             32.00000              44.00000  0.99490 3.45000    0.58000
# 1595             39.00000              51.00000  0.99512 3.52000    0.76000
# 1596             29.00000              40.00000  0.99574 3.42000    0.75000
# 1597             32.00000              44.00000  0.99547 3.57000    0.71000
# 1598             18.00000              42.00000  0.99549 3.39000    0.66000
#
#       alcohol  quality
# 1589  9.20000        5
# 1590 11.60000        6
# 1591 11.60000        6
# 1592 11.00000        6
# 1593  9.50000        6
# 1594 10.50000        5
# 1595 11.20000        6
# 1596 11.00000        6
# 1597 10.20000        5
# 1598 11.00000        6

# %%
display(ww.head(10))
display(ww.tail(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        7.00000           0.27000      0.36000        20.70000    0.04500
# 1        6.30000           0.30000      0.34000         1.60000    0.04900
# 2        8.10000           0.28000      0.40000         6.90000    0.05000
# 3        7.20000           0.23000      0.32000         8.50000    0.05800
# 4        7.20000           0.23000      0.32000         8.50000    0.05800
# 5        8.10000           0.28000      0.40000         6.90000    0.05000
# 6        6.20000           0.32000      0.16000         7.00000    0.04500
# 7        7.00000           0.27000      0.36000        20.70000    0.04500
# 8        6.30000           0.30000      0.34000         1.60000    0.04900
# 9        8.10000           0.22000      0.43000         1.50000    0.04400
#
#    free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 0             45.00000             170.00000  1.00100 3.00000    0.45000
# 1             14.00000             132.00000  0.99400 3.30000    0.49000
# 2             30.00000              97.00000  0.99510 3.26000    0.44000
# 3             47.00000             186.00000  0.99560 3.19000    0.40000
# 4             47.00000             186.00000  0.99560 3.19000    0.40000
# 5             30.00000              97.00000  0.99510 3.26000    0.44000
# 6             30.00000             136.00000  0.99490 3.18000    0.47000
# 7             45.00000             170.00000  1.00100 3.00000    0.45000
# 8             14.00000             132.00000  0.99400 3.30000    0.49000
# 9             28.00000             129.00000  0.99380 3.22000    0.45000
#
#    alcohol  quality
# 0  8.80000        6
# 1  9.50000        6
# 2 10.10000        6
# 3  9.90000        6
# 4  9.90000        6
# 5 10.10000        6
# 6  9.60000        6
# 7  8.80000        6
# 8  9.50000        6
# 9 11.00000        6
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888        6.80000           0.22000      0.36000         1.20000    0.05200
# 4889        4.90000           0.23500      0.27000        11.75000    0.03000
# 4890        6.10000           0.34000      0.29000         2.20000    0.03600
# 4891        5.70000           0.21000      0.32000         0.90000    0.03800
# 4892        6.50000           0.23000      0.38000         1.30000    0.03200
# 4893        6.20000           0.21000      0.29000         1.60000    0.03900
# 4894        6.60000           0.32000      0.36000         8.00000    0.04700
# 4895        6.50000           0.24000      0.19000         1.20000    0.04100
# 4896        5.50000           0.29000      0.30000         1.10000    0.02200
# 4897        6.00000           0.21000      0.38000         0.80000    0.02000
#
#       free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 4888             38.00000             127.00000  0.99330 3.04000    0.54000
# 4889             34.00000             118.00000  0.99540 3.07000    0.50000
# 4890             25.00000             100.00000  0.98938 3.06000    0.44000
# 4891             38.00000             121.00000  0.99074 3.24000    0.46000
# 4892             29.00000             112.00000  0.99298 3.29000    0.54000
# 4893             24.00000              92.00000  0.99114 3.27000    0.50000
# 4894             57.00000             168.00000  0.99490 3.15000    0.46000
# 4895             30.00000             111.00000  0.99254 2.99000    0.46000
# 4896             20.00000             110.00000  0.98869 3.34000    0.38000
# 4897             22.00000              98.00000  0.98941 3.26000    0.32000
#
#       alcohol  quality
# 4888  9.20000        5
# 4889  9.40000        6
# 4890 11.80000        6
# 4891 10.60000        6
# 4892  9.70000        5
# 4893 11.20000        6
# 4894  9.60000        5
# 4895  9.40000        6
# 4896 12.80000        7
# 4897 11.80000        6

# %%
# Check for any missing data, kind of data types. View the Shape of the Datarame
print(rw.info(), '\n', rw.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
#  (1599, 12)

# %%
print(ww.info(), '\n', ww.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None
#  (4898, 12)

# %%
# Count of NaNs
print(rw.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(ww.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
display(rw.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     1599.00000        1599.00000   1599.00000      1599.00000
# mean         8.31964           0.52782      0.27098         2.53881
# std          1.74110           0.17906      0.19480         1.40993
# min          4.60000           0.12000      0.00000         0.90000
# 25%          7.10000           0.39000      0.09000         1.90000
# 50%          7.90000           0.52000      0.26000         2.20000
# 75%          9.20000           0.64000      0.42000         2.60000
# max         15.90000           1.58000      1.00000        15.50000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count 1599.00000           1599.00000            1599.00000 1599.00000
# mean     0.08747             15.87492              46.46779    0.99675
# std      0.04707             10.46016              32.89532    0.00189
# min      0.01200              1.00000               6.00000    0.99007
# 25%      0.07000              7.00000              22.00000    0.99560
# 50%      0.07900             14.00000              38.00000    0.99675
# 75%      0.09000             21.00000              62.00000    0.99784
# max      0.61100             72.00000             289.00000    1.00369
#
#               pH  sulphates    alcohol    quality
# count 1599.00000 1599.00000 1599.00000 1599.00000
# mean     3.31111    0.65815   10.42298    5.63602
# std      0.15439    0.16951    1.06567    0.80757
# min      2.74000    0.33000    8.40000    3.00000
# 25%      3.21000    0.55000    9.50000    5.00000
# 50%      3.31000    0.62000   10.20000    6.00000
# 75%      3.40000    0.73000   11.10000    6.00000
# max      4.01000    2.00000   14.90000    8.00000

# %%
display(ww.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     4898.00000        4898.00000   4898.00000      4898.00000
# mean         6.85479           0.27824      0.33419         6.39141
# std          0.84387           0.10079      0.12102         5.07206
# min          3.80000           0.08000      0.00000         0.60000
# 25%          6.30000           0.21000      0.27000         1.70000
# 50%          6.80000           0.26000      0.32000         5.20000
# 75%          7.30000           0.32000      0.39000         9.90000
# max         14.20000           1.10000      1.66000        65.80000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count 4898.00000           4898.00000            4898.00000 4898.00000
# mean     0.04577             35.30808             138.36066    0.99403
# std      0.02185             17.00714              42.49806    0.00299
# min      0.00900              2.00000               9.00000    0.98711
# 25%      0.03600             23.00000             108.00000    0.99172
# 50%      0.04300             34.00000             134.00000    0.99374
# 75%      0.05000             46.00000             167.00000    0.99610
# max      0.34600            289.00000             440.00000    1.03898
#
#               pH  sulphates    alcohol    quality
# count 4898.00000 4898.00000 4898.00000 4898.00000
# mean     3.18827    0.48985   10.51427    5.87791
# std      0.15100    0.11413    1.23062    0.88564
# min      2.72000    0.22000    8.00000    3.00000
# 25%      3.09000    0.41000    9.50000    5.00000
# 50%      3.18000    0.47000   10.40000    6.00000
# 75%      3.28000    0.55000   11.40000    6.00000
# max      3.82000    1.08000   14.20000    9.00000

# %%
# Remove Duplicates
# rw = rw.drop_duplicates()
# ww = ww.drop_duplicates()

# %%
# Creating a new column called "quality label"
rw["quality label"] = rw["quality"].apply(
    lambda value: "low" if value < 5 else "medium" if value < 7 else "high"
)
ww["quality label"] = ww["quality"].apply(
    lambda value: "low" if value < 5 else "medium" if value < 7 else "high"
)

# Transforming these labels into categrical data type
categories=["low", "medium", "high"]
rw["quality label"] = pd.Categorical(
    rw["quality label"], categories=categories
)
ww["quality label"] = pd.Categorical(
    ww["quality label"], categories=categories
)

# %%
# Creating a DataFrame of both wines

rw['wine_type'] = 'Red'
ww['wine_type'] = 'White'
rw['wine_type'] = pd.Categorical(rw['wine_type'], categories=['Red'])
ww['wine_type'] = pd.Categorical(ww['wine_type'], categories=['White'])
print(rw.shape[0] + ww.shape[0])
wine = pd.merge(rw, ww, how='outer')
print(wine.shape)
display(wine.head(5))
display(wine.tail(5))
# Out:
# 6497
# (6497, 14)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        7.40000           0.70000      0.00000         1.90000    0.07600
# 1        7.40000           0.70000      0.00000         1.90000    0.07600
# 2        7.80000           0.88000      0.00000         2.60000    0.09800
# 3        7.80000           0.76000      0.04000         2.30000    0.09200
# 4       11.20000           0.28000      0.56000         1.90000    0.07500
#
#    free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 0             11.00000              34.00000  0.99780 3.51000    0.56000
# 1             11.00000              34.00000  0.99780 3.51000    0.56000
# 2             25.00000              67.00000  0.99680 3.20000    0.68000
# 3             15.00000              54.00000  0.99700 3.26000    0.65000
# 4             17.00000              60.00000  0.99800 3.16000    0.58000
#
#    alcohol  quality quality label wine_type
# 0  9.40000        5        medium       Red
# 1  9.40000        5        medium       Red
# 2  9.80000        5        medium       Red
# 3  9.80000        5        medium       Red
# 4  9.80000        6        medium       Red
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492        6.20000           0.21000      0.29000         1.60000    0.03900
# 6493        6.60000           0.32000      0.36000         8.00000    0.04700
# 6494        6.50000           0.24000      0.19000         1.20000    0.04100
# 6495        5.50000           0.29000      0.30000         1.10000    0.02200
# 6496        6.00000           0.21000      0.38000         0.80000    0.02000
#
#       free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 6492             24.00000              92.00000  0.99114 3.27000    0.50000
# 6493             57.00000             168.00000  0.99490 3.15000    0.46000
# 6494             30.00000             111.00000  0.99254 2.99000    0.46000
# 6495             20.00000             110.00000  0.98869 3.34000    0.38000
# 6496             22.00000              98.00000  0.98941 3.26000    0.32000
#
#       alcohol  quality quality label wine_type
# 6492 11.20000        6        medium     White
# 6493  9.60000        5        medium     White
# 6494  9.40000        6        medium     White
# 6495 12.80000        7          high     White
# 6496 11.80000        6        medium     White

# %%
cols = [
    "residual sugar",
    "total sulfur dioxide",
    "sulphates",
    "citric acid",
    "volatile acidity",
    "quality",
]
pd.concat(
    [rw[cols].describe(), ww[cols].describe()],
    axis=1,
    keys=["Red Wines Stats", "White Wines Stats"],
)

# White Wine's Residual Sugar mean value is considerably higher
# Total Sulfur Dioxide mean value of White Wine is 3x higher that Red Wine's
# Volatile Acidity mean value of Red Wine is 2x higher that the White Wine's
# Out:
#       Red Wines Stats                                              \
#        residual sugar total sulfur dioxide  sulphates citric acid
# count      1599.00000           1599.00000 1599.00000  1599.00000
# mean          2.53881             46.46779    0.65815     0.27098
# std           1.40993             32.89532    0.16951     0.19480
# min           0.90000              6.00000    0.33000     0.00000
# 25%           1.90000             22.00000    0.55000     0.09000
# 50%           2.20000             38.00000    0.62000     0.26000
# 75%           2.60000             62.00000    0.73000     0.42000
# max          15.50000            289.00000    2.00000     1.00000
#
#                                   White Wines Stats                       \
#       volatile acidity    quality    residual sugar total sulfur dioxide
# count       1599.00000 1599.00000        4898.00000           4898.00000
# mean           0.52782    5.63602           6.39141            138.36066
# std            0.17906    0.80757           5.07206             42.49806
# min            0.12000    3.00000           0.60000              9.00000
# 25%            0.39000    5.00000           1.70000            108.00000
# 50%            0.52000    6.00000           5.20000            134.00000
# 75%            0.64000    6.00000           9.90000            167.00000
# max            1.58000    8.00000          65.80000            440.00000
#
#
#        sulphates citric acid volatile acidity    quality
# count 4898.00000  4898.00000       4898.00000 4898.00000
# mean     0.48985     0.33419          0.27824    5.87791
# std      0.11413     0.12102          0.10079    0.88564
# min      0.22000     0.00000          0.08000    3.00000
# 25%      0.41000     0.27000          0.21000    5.00000
# 50%      0.47000     0.32000          0.26000    6.00000
# 75%      0.55000     0.39000          0.32000    6.00000
# max      1.08000     1.66000          1.10000    9.00000

# %%
sns.set_theme()

colors = ["#e60c34", "#fda929", "#19ae1d"]
colors_a = ["#e60c3460", "#fda92960", "#19ae1dff"]
colors_e = ["#e60c34", "#fd5a29", "#fda929", "#fcdf1c", "#73bf1d", "#19ae1d", "#1fd161"]
colors_w = ["#f0f0f0", "#c2006b"]

# Plot 1. Wine Type Count

wine["wine_type"].value_counts().plot(
    kind="pie",
    figsize=(6, 6),
    textprops={"fontsize": 20},
    autopct="%1.1f%%",
    colors=colors_w,
    wedgeprops={"edgecolor": "#000000", "linewidth": 2},
    startangle=270
)

plt.title("Wine Type Count", fontsize=25)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Plot 2. Quality Labels Count

sns.countplot(data=wine, x='quality', palette=colors_e, edgecolor='black')
plt.ylabel('Count', fontsize=15)
plt.xlabel('Quality', fontsize=15)


fig, axes = plt.subplots(1, 2, sharey=True, figsize=(12, 5))

sns.countplot(data=rw, x='quality label', ax=axes[0], palette=colors, edgecolor='black')
axes[0].set_title('Red Wine', fontsize=20, pad=20)
axes[1].set_title('White Wine', fontsize=20, pad=20)
sns.countplot(data=ww, x='quality label', ax=axes[1], palette=colors, edgecolor='black')
[ax.set_ylabel("Count", fontsize=15, labelpad=15) for ax in axes]
[ax.set_xlabel("Quality", fontsize=15, labelpad=15) for ax in axes]
# Out:
# [Text(0.5, 0, 'Quality'), Text(0.5, 0, 'Quality')]

# %%
# Plot 3. Wine Heatmap

data_list = [wine, rw, ww]
n = len(data_list)
wine_names= ['Wine', 'Red Wine', 'White Wine']
mask = np.triu(np.ones_like(rw.corr(numeric_only=True)))

fig, axes = plt.subplots(n, 1, figsize=(10, 21))
fig.tight_layout(pad=9)


for i in range(n):
    sns.heatmap(
        data_list[i].corr(numeric_only=True),
        annot=True,
        fmt=".2f",
        cmap="RdYlGn",
        mask=mask,
        ax=axes[i],
    )
    axes[i].set_title(wine_names[i], fontsize=15, pad=10)

# %%
# Plot 4. Wine Quality - Alcohol Content/pH

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

fig.suptitle("Wine Quality - Alcohol Content/pH", fontsize=20)

sns.boxplot(data=wine, x="quality label", y="alcohol", ax=axes[0], palette=colors)
axes[0].set_ylabel("Alcohol %", fontsize=15, labelpad=15)
axes[0].set_xlabel("Quality", fontsize=15, labelpad=20)

sns.boxplot(data=wine, x="quality label", y="pH", ax=axes[1], palette=colors)
axes[1].set_ylabel("pH", fontsize=15, labelpad=15)
axes[1].set_xlabel("Quality", fontsize=15, labelpad=20)
# Out:
# Text(0.5, 0, 'Quality')

# %%
# Function for filtering outliers 

def filter_o(data):
    d = data
    if d.name == 'free sulfur dioxide':
        d = data[data < 100]
    elif d.name == 'total sulfur dioxide':
        d = data[data < 300]
    elif d.name == 'chlorides':
        d = data[data < 0.12]
    elif d.name == 'density':
        d = data[data < 1.01]
    elif d.name == 'volatile acidity':
        d = data[data < 1.2]
    elif d.name == 'residual sugar':
        d = data[data < 20]
    elif d.name == 'citric acid':
        d = data[data < 1]
    elif d.name == 'sulphates':
        d = data[data < 1.3]
    return d

# def filter_o(data, x):
    # q = d.quantile([0, 0.25, 0.75, 1])
    # iqr = q[0.25] - q[0.75]
    # mask = d.between(q[0], q[0.75]*2, inclusive='right')
    # return data.loc[mask, d.name]
    # return d

# %%
# Plot 5. Red Wine Properties to Quality Label Correlation


def boxplot_quality(data, prop_list, type):
    n, m = 2, 3
    fig, axes = plt.subplots(n, m, figsize=(15, 10))
    k = 0
    if type == "box":
        for i in range(n):
            k = i * m
            for j in range(m):
                sns.boxplot(
                    data=data,
                    y=filter_o(data[prop_list[k + j]]),
                    x="quality label",
                    ax=axes[i][j],
                    palette=colors,
                )
    else:
        for i in range(n):
            k = i * m
            for j in range(m):
                sns.boxenplot(
                    data=data,
                    y=filter_o(data[prop_list[k + j]]),
                    x="quality",
                    ax=axes[i][j],
                    palette=colors_e,
                )
    if data.equals(rw):
        fig.suptitle("Red Wine Properties to Quality Label Correlation ", fontsize=20)
        axes[1][2].set_visible(False)
    else:
        fig.suptitle("White Wine Properties to Quality Label Correlation ", fontsize=20)
        axes[0][2].set_visible(False)
    plt.show()


rw_props_list = [
    "sulphates",
    "citric acid",
    "alcohol",
    "density",
    "volatile acidity",
    "citric acid",
]
ww_props_list = [
    "pH",
    "alcohol",
    "citric acid",
    "density",
    "chlorides",
    "volatile acidity",
]
boxplot_quality(rw, rw_props_list, "box")
boxplot_quality(rw, rw_props_list, "boxen")
boxplot_quality(ww, ww_props_list, "box")
boxplot_quality(ww, ww_props_list, "boxen")

# %%
# Plot 6. Univariate Analysis of Red Wine compared to White Wine

n, m = 4, 3
fig, axes = plt.subplots(n, m, figsize=(15, 15))
fig.suptitle(
    "Univariate Analysis of Red Wine compared to White Wine", fontsize=20, y=0.92
)

k = 0

for i in range(n):
    k = i * m
    for j in range(m):
        sns.kdeplot(
        data=rw,
        x=filter_o(rw.iloc[:, k+j]),
        ax=axes[i][j],
        color=colors_w[1],
        fill=True,
        cut = 10
        )
        sns.kdeplot(
        data=ww,
        x=filter_o(ww.iloc[:, k+j]),
        ax=axes[i][j], 
        color=colors_e[5],
        fill=True
        )
        axes[i][j].set(yticklabels=[])
        axes[i][j].set(ylabel=None)
        
axes[3][2].set_visible(False)

# %%
# Plot 8. Finding a factor 0 < k < 1, that would represent quality based on wine properties.
# The bigger the factor, the better the quality suppose to be.

k = (wine["pH"] + wine["alcohol"]) / (
    wine["density"] + wine["volatile acidity"] + wine["chlorides"]
)
wine["factor"] = k / k.abs().max()
k_r = (rw["citric acid"] + rw["alcohol"]) / (rw["density"] + rw["volatile acidity"])
rw["factor"] = k_r / k_r.abs().max()
k_w = (ww["pH"] + ww["alcohol"]) / (
    ww["density"] + ww["volatile acidity"] + ww["chlorides"]
)
ww["factor"] = k_w / k_w.abs().max()

n = 3
fig, axes = plt.subplots(1, n, figsize=(15, 5), sharey=True)
fig.suptitle("Quality Factor", fontsize=20, y=1.1)
q = 'quality'

for i in range(n):
    c = colors_e[:-1] if i == 1 else colors_e
    axes[i].set_title(wine_names[i], fontsize=15)
    sns.stripplot(
        data=data_list[i],
        x=q,
        y="factor",
        palette=c,
        hue=q,
        ax=axes[i],
        s=5,
        jitter=0.45,
        alpha=0.6,
    )
    # axes[0].set(ylim=(0.45, 0.8))
    axes[i].legend([], [], frameon=False)

# %%
# Testing the probability and ANOVA of the factor
from scipy import stats


def k_prob(data, q):
    q_labels = ["low", "medium", "high"]
    n = q_labels.index(q)
    dql = data["quality label"]
    if n == 0:
        a = data[(data["factor"] < data[dql == q]["factor"].mean()) & (dql == q)]
    else:
        a = data[
            (data["factor"] > data[dql == q_labels[n - 1]]["factor"].mean())
            & (dql == q)
        ]
    return a.value_counts().count() / data[dql == q].value_counts().count()


print(k_prob(rw, "low"), k_prob(rw, "medium"), k_prob(rw, "high"))
print(k_prob(ww, "low"), k_prob(ww, "medium"), k_prob(ww, "high"))
print(k_prob(wine, "low"), k_prob(wine, "medium"), k_prob(wine, "high"))
print("\n")

F, p = stats.f_oneway(
    rw[rw["quality label"] == "low"]["factor"],
    rw[rw["quality label"] == "medium"]["factor"],
    rw[rw["quality label"] == "high"]["factor"],
)
print(
    "ANOVA test for mean factor levels across wine samples with different quality ratings"
)
print("F Statistic:", F, "\tp-value:", p)
# Out:
# 0.6031746031746031 0.7122302158273381 0.9130434782608695
# 0.4682080924855491 0.7246034424569693 0.9042424242424243
# 0.4830508474576271 0.699877300613497 0.9058473736372646
#
#
# ANOVA test for mean factor levels across wine samples with different quality ratings
# F Statistic: 216.75309578560012 	p-value: 5.281048136755847e-84

# %%
# Plot 9. Bivariate Analysis. KDE and Scatter Plots.


def kde_scatter_plot(data, x, y):
    fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
    sns.kdeplot(
        data=data, y=y, x=x, hue="quality label", palette=colors, levels=10, ax=axes[0]
    )
    sns.scatterplot(
        data=data,
        y=y,
        x=x,
        hue="quality label",
        palette=colors_a,
        ax=axes[1],
        marker="s",
        s=30,
        linewidth=0,
    )
    plt.show()


kde_scatter_plot(wine[wine["residual sugar"] < 20], "residual sugar", "alcohol")
kde_scatter_plot(
    rw[rw["total sulfur dioxide"] < 200], "volatile acidity", "total sulfur dioxide"
)
kde_scatter_plot(rw, "sulphates", "alcohol")

# %%
# ANOVA Testing

from scipy import stats

F, p = stats.f_oneway(
    rw[rw["quality label"] == "low"]["alcohol"],
    rw[rw["quality label"] == "medium"]["alcohol"],
    rw[rw["quality label"] == "high"]["alcohol"],
)
print(
    "ANOVA test for mean alcohol levels across wine samples with different quality ratings"
)
print("F Statistic:", F, "\tp-value:", p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 158.77759051145452 	p-value: 1.291616119044909e-63
